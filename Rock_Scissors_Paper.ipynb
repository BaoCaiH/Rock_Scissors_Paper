# %%
def game_play(score_board):
    
    options = ['Rock', 'Scissors', 'Paper']
    
    option_translate = {
        'rock' : 'Rock',
        'r' : 'Rock',
        'scissor' : 'Scissors',
        'scissors' : 'Scissors',
        's' : 'Scissors',
        'paper' : 'Paper',
        'p' : 'Paper'
    }
    
    player_choice = input('Rock, Scissors or Paper? (Rock is the default choice) ')
    
    if player_choice == '':
        player_choice = 'Rock'
    
    player_choice = option_translate[player_choice.lower()]
    
    computer_choice = options[random.randint(0, 2)]
    
    print('You chose {} and computer chose {}'.format(player_choice, computer_choice))
    
    if player_choice == computer_choice:
        print('Draw!')
    elif player_choice == 'Rock':
        if computer_choice == 'Scissors':
            print('You win!')
            score_board['player'] += 1
        elif computer_choice == 'Paper':
            print('Computer win!')
            score_board['computer'] += 1
    elif player_choice == 'Scissors':
        if computer_choice == 'Paper':
            print('You win!')
            score_board['player'] += 1
        elif computer_choice == 'Rock':
            print('Computer win!')
            score_board['computer'] += 1
    elif player_choice == 'Paper':
        if computer_choice == 'Rock':
            print('You win!')
            score_board['player'] += 1
        elif computer_choice == 'Scissors':
            print('Computer win!')
            score_board['computer'] += 1
    return score_board

# %%
def play_rock_scissors_paper():
    
    import random
    
    play = 'y'
    
    score_board = {
        'player' : 0,
        'computer' : 0
    }
    
    while play == 'y':
        try:
            score_board = game_play(score_board)
            print(score_board)
            play = input('Do you want to play again? (Y/n) ')
            play = play.lower()
            if play == '' or play =='y':
                play = 'y'
            elif play != 'n':
                print("I don't understand that so I assume you don't want to play again, yes?")
                play = 'n'
            
            if play == 'n':
                print('See ya!')
        except KeyError:
            print('Check your option, you can only choose among Rock, Scissors and Paper')

# %%
play_rock_scissors_paper()
# Out:
# Rock, Scissors or Paper? (Rock is the default choice) r
# You chose Rock and computer chose Paper
# Computer win!
# {'player': 0, 'computer': 1}
# Do you want to play again? (Y/n) y
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Rock
# Draw!
# {'player': 0, 'computer': 1}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Rock
# Draw!
# {'player': 0, 'computer': 1}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Paper
# Computer win!
# {'player': 0, 'computer': 2}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Paper
# Computer win!
# {'player': 0, 'computer': 3}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Paper
# Computer win!
# {'player': 0, 'computer': 4}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Paper
# Computer win!
# {'player': 0, 'computer': 5}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Paper
# Computer win!
# {'player': 0, 'computer': 6}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Scissors
# You win!
# {'player': 1, 'computer': 6}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Rock
# Draw!
# {'player': 1, 'computer': 6}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Paper
# Computer win!
# {'player': 1, 'computer': 7}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Scissors
# You win!
# {'player': 2, 'computer': 7}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Scissors
# You win!
# {'player': 3, 'computer': 7}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Rock
# Draw!
# {'player': 3, 'computer': 7}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Rock
# Draw!
# {'player': 3, 'computer': 7}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Scissors
# You win!
# {'player': 4, 'computer': 7}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Rock
# Draw!
# {'player': 4, 'computer': 7}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Rock
# Draw!
# {'player': 4, 'computer': 7}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Rock
# Draw!
# {'player': 4, 'computer': 7}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Scissors
# You win!
# {'player': 5, 'computer': 7}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Rock
# Draw!
# {'player': 5, 'computer': 7}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Paper
# Computer win!
# {'player': 5, 'computer': 8}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Rock
# Draw!
# {'player': 5, 'computer': 8}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Scissors
# You win!
# {'player': 6, 'computer': 8}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Scissors
# You win!
# {'player': 7, 'computer': 8}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Rock
# Draw!
# {'player': 7, 'computer': 8}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Scissors
# You win!
# {'player': 8, 'computer': 8}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Paper
# Computer win!
# {'player': 8, 'computer': 9}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Paper
# Computer win!
# {'player': 8, 'computer': 10}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Scissors
# You win!
# {'player': 9, 'computer': 10}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Rock
# Draw!
# {'player': 9, 'computer': 10}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Scissors
# You win!
# {'player': 10, 'computer': 10}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Rock
# Draw!
# {'player': 10, 'computer': 10}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Scissors
# You win!
# {'player': 11, 'computer': 10}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Rock
# Draw!
# {'player': 11, 'computer': 10}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Scissors
# You win!
# {'player': 12, 'computer': 10}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Paper
# Computer win!
# {'player': 12, 'computer': 11}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Scissors
# You win!
# {'player': 13, 'computer': 11}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Rock
# Draw!
# {'player': 13, 'computer': 11}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Scissors
# You win!
# {'player': 14, 'computer': 11}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Scissors
# You win!
# {'player': 15, 'computer': 11}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Scissors
# You win!
# {'player': 16, 'computer': 11}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Paper
# Computer win!
# {'player': 16, 'computer': 12}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Rock
# Draw!
# {'player': 16, 'computer': 12}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Scissors
# You win!
# {'player': 17, 'computer': 12}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Scissors
# You win!
# {'player': 18, 'computer': 12}
# Do you want to play again? (Y/n)
# Rock, Scissors or Paper? (Rock is the default choice) n
# Check your option, you can only choose among Rock, Scissors and Paper
# Rock, Scissors or Paper? (Rock is the default choice)
# You chose Rock and computer chose Paper
# Computer win!
# {'player': 18, 'computer': 13}
# Do you want to play again? (Y/n) n
# See ya!
